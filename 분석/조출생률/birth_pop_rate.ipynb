# %% [markdown]
# ## 조출생율
# - 자료출처
# <br>통계청,「인구동향조사」, 2021, 2022.12.20, 시군구/성/연령(5세)별 주민등록연앙인구
# <br>통계청,「인구동향조사」, 2021, 2022.12.21, 시군구/성/출산순위별 출생

# %%
import pandas as pd

birth_pop=pd.read_csv('./birth_pop.csv',skipinitialspace=True)
total_pop=pd.read_csv('../total_pop/total_pop.csv',skipinitialspace=True)
birth_pop['시군구별'].str.strip()
total_pop['행정구역(시군구)별'].str.strip()
birth_pop.drop('2021',axis=1, inplace=True)
birth_pop
# Out:
#            시군구별  2016  2017  2018  2019  2020
# 0      부산광역시 중구   211   174   163   112    94
# 1      부산광역시 서구   574   458   426   386   359
# 2      부산광역시 동구   436   373   321   334   347
# 3     부산광역시 영도구   619   469   404   346   289
# 4    부산광역시 부산진구  2692  2288  2018  1695  1468
# ..          ...   ...   ...   ...   ...   ...
# 218    경상남도 하동군   228   188   176   185   136
# 219    경상남도 산청군   207   191   143   145    86
# 220    경상남도 함양군   178   160   150   136   105
# 221    경상남도 거창군   352   294   266   238   238
# 222    경상남도 합천군   174   123   125   137   107
#
# [223 rows x 6 columns]

# %%
total_pop
# Out:
#      행정구역(시군구)별  total_2016  total_2017  total_2018  total_2019  total_2020
# 0      부산광역시 중구     44191.5     43386.0     42206.5     41066.5     40445.5
# 1      부산광역시 서구    112041.5    109135.5    107981.5    107094.5    105948.0
# 2      부산광역시 동구     89046.5     87490.5     86074.5     85757.0     86801.0
# 3     부산광역시 영도구    125772.5    122860.5    119749.5    116364.5    113042.5
# 4    부산광역시 부산진구    373849.5    368927.5    361954.5    355134.5    354107.5
# ..          ...         ...         ...         ...         ...         ...
# 217    경상남도 하동군     49639.5     48933.0     47890.0     46756.0     45389.5
# 218    경상남도 산청군     35772.0     35918.5     35853.0     35389.5     34845.0
# 219    경상남도 함양군     39952.0     39870.0     39778.0     39519.0     39045.0
# 220    경상남도 거창군     62894.5     62656.5     62244.5     61957.5     61478.0
# 221    경상남도 합천군     48109.0     47048.5     46005.5     45111.5     44159.5
#
# [222 rows x 6 columns]

# %%
birth_pop.rename(columns={'시군구별':'sigungu',
                           'birth_2016':'2016',
                           'birth_2017':'2017',
                           'birth_2018':'2018',
                           'birth_2019':'2019',
                           'birth_2020':'2020'}, inplace=True)
birth_pop.set_index('sigungu', inplace=True)
birth_pop.sort_index(inplace=True)
birth_pop
# Out:
#           2016  2017  2018  2019  2020
# sigungu
# 강원도 강릉시   1236  1084  1036   964   950
# 강원도 고성군    147   135   106   127    98
# 강원도 동해시    662   561   472   422   404
# 강원도 삼척시    381   337   341   366   358
# 강원도 속초시    517   383   416   414   415
# ...        ...   ...   ...   ...   ...
# 충청북도 증평군   402   367   324   268   199
# 충청북도 진천군   533   513   545   619   525
# 충청북도 청원구  2413  2105  2060  1706  1464
# 충청북도 충주시  1428  1234  1155  1100  1042
# 충청북도 흥덕구  2402  2230  2043  1830  1836
#
# [223 rows x 5 columns]

# %%
birth_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 223 entries, 강원도 강릉시 to 충청북도 흥덕구
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2016    223 non-null    int64
#  1   2017    223 non-null    int64
#  2   2018    223 non-null    int64
#  3   2019    223 non-null    int64
#  4   2020    223 non-null    int64
# dtypes: int64(5)
# memory usage: 10.5+ KB

# %%
total_pop.rename(columns={'행정구역(시군구)별':'sigungu',
                           'total_2016':'2016',
                           'total_2017':'2017',
                           'total_2018':'2018',
                           'total_2019':'2019',
                           'total_2020':'2020'}, inplace=True)
total_pop.set_index('sigungu', inplace=True)
total_pop.sort_index(inplace=True)
total_pop
# Out:
#               2016      2017      2018      2019      2020
# sigungu
# 강원도 강릉시   212434.0  212129.0  211716.0  211445.5  211643.0
# 강원도 고성군    29867.0   29855.0   28873.0   27484.0   26791.5
# 강원도 동해시    92854.5   92327.0   91313.5   90147.0   89814.0
# 강원도 삼척시    69481.5   68371.0   67786.5   67156.5   65623.0
# 강원도 속초시    81180.0   81307.5   81248.5   80999.0   81496.5
# ...            ...       ...       ...       ...       ...
# 충청북도 증평군   36808.5   37357.5   37353.5   37148.5   36893.0
# 충청북도 진천군   68446.5   71295.0   75445.5   79174.5   81957.5
# 충청북도 청원구  185558.5  191438.5  194656.0  195690.0  194256.0
# 충청북도 충주시  206784.5  206912.0  207998.5  209230.5  209083.5
# 충청북도 흥덕구  252102.0  252342.0  252741.5  256841.5  262632.0
#
# [222 rows x 5 columns]

# %%
total_pop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 222 entries, 강원도 강릉시 to 충청북도 흥덕구
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2016    222 non-null    float64
#  1   2017    222 non-null    float64
#  2   2018    222 non-null    float64
#  3   2019    222 non-null    float64
#  4   2020    222 non-null    float64
# dtypes: float64(5)
# memory usage: 10.4+ KB

# %%
birth_rate=birth_pop/total_pop*1000
birth_rate['인구감소지수 분류']='안심지역'

# %%
ingu_89 = ['부산광역시 동구', '부산광역시 서구', '부산광역시 영도구', '대구광역시 남구', '대구광역시 서구',
           '인천광역시 강화군', '인천광역시 옹진군', '경기도 가평군', '경기도 연천군', '강원도 고성군', '강원도 삼척시',
          '강원도 양구군', '강원도 양양군', '강원도 영월군', '강원도 정선군', '강원도 철원군', '강원도 태백시',
          '강원도 평창군', '강원도 홍천군', '강원도 화천군', '강원도 횡성군', '충청북도 괴산군', '충청북도 단양군',
          '충청북도 보은군', '충청북도 영동군', '충청북도 옥천군', '충청북도 제천시', '충청남도 공주시', '충청남도 금산군',
          '충청남도 논산시', '충청남도 보령시', '충청남도 부여군', '충청남도 서천군', '충청남도 예산군', '충청남도 청양군',
          '충청남도 태안군', '전라북도 고창군', '전라북도 김제시', '전라북도 남원시', '전라북도 무주군', '전라북도 부안군',
          '전라북도 순창군', '전라북도 임실군', '전라북도 장수군', '전라북도 정읍시', '전라북도 진안군', '전라남도 강진군',
          '전라남도 고흥군', '전라남도 곡성군', '전라남도 구례군', '전라남도 담양군', '전라남도 보성군', '전라남도 신안군',
          '전라남도 영광군', '전라남도 영암군', '전라남도 완도군', '전라남도 장성군', '전라남도 장흥군', '전라남도 진도군',
          '전라남도 함평군', '전라남도 해남군', '전라남도 화순군', '경상북도 고령군', '경상북도 군위군', '경상북도 문경시',
          '경상북도 봉화군', '경상북도 상주시', '경상북도 성주군', '경상북도 안동시', '경상북도 영덕군', '경상북도 영양군',
          '경상북도 영주시', '경상북도 영천시', '경상북도 울릉군', '경상북도 울진군', '경상북도 의성군', '경상북도 청도군',
          '경상북도 청송군', '경상남도 거창군', '경상남도 고성군', '경상남도 남해군', '경상남도 밀양시', '경상남도 산청군',
          '경상남도 의령군', '경상남도 창녕군', '경상남도 하동군', '경상남도 함안군', '경상남도 함양군', '경상남도 합천군']

# %%
semi_18 = ['대전광역시 동구','인천광역시 동구','부산광역시 중구','부산광역시 금정구','광주광역시 동구','경상남도 통영시',
           '강원도 강릉시','강원도 동해시','대전광역시 중구','경상북도 경주시','경상남도 사천시', '경상북도 김천시',
          '대전광역시 대덕구','강원도 인제군','전라북도 익산시','경기도 동두천시','강원도 속초시','경기도 포천시']

# %%
for i in ingu_89 :
    birth_rate.loc[i,'인구감소지수 분류'] = '인구감소지역'

for i in semi_18 :
    birth_rate.loc[i,'인구감소지수 분류'] = '관심지역'

birth_rate
# Out:
#                2016       2017       2018      2019      2020 인구감소지수 분류
# sigungu
# 강원도 강릉시    5.818278   5.110098   4.893348  4.559094  4.488691      관심지역
# 강원도 고성군    4.921820   4.521856   3.671250  4.620870  3.657877    인구감소지역
# 강원도 동해시    7.129434   6.076229   5.169006  4.681243  4.498185      관심지역
# 강원도 삼척시    5.483474   4.928990   5.030500  5.449956  5.455404    인구감소지역
# 강원도 속초시    6.368564   4.710513   5.120095  5.111174  5.092243      관심지역
# ...             ...        ...        ...       ...       ...       ...
# 충청북도 증평군  10.921390   9.823998   8.673886  7.214289  5.393977      안심지역
# 충청북도 진천군   7.787104   7.195456   7.223758  7.818174  6.405759      안심지역
# 충청북도 청원구  13.003985  10.995698  10.582772  8.717870  7.536447      안심지역
# 충청북도 충주시   6.905740   5.963888   5.552925  5.257360  4.983655      안심지역
# 충청북도 흥덕구   9.527890   8.837213   8.083358  7.125017  6.990770      안심지역
#
# [223 rows x 6 columns]

# %%
birth_rate_g = pd.DataFrame(birth_rate['2020'])
birth_rate_g['total_2020']=total_pop['2020']
birth_rate_g['인구감소지수 분류']=birth_rate['인구감소지수 분류']
birth_rate_g
# Out:
#               2020  total_2020 인구감소지수 분류
# sigungu
# 강원도 강릉시   4.488691    211643.0      관심지역
# 강원도 고성군   3.657877     26791.5    인구감소지역
# 강원도 동해시   4.498185     89814.0      관심지역
# 강원도 삼척시   5.455404     65623.0    인구감소지역
# 강원도 속초시   5.092243     81496.5      관심지역
# ...            ...         ...       ...
# 충청북도 증평군  5.393977     36893.0      안심지역
# 충청북도 진천군  6.405759     81957.5      안심지역
# 충청북도 청원구  7.536447    194256.0      안심지역
# 충청북도 충주시  4.983655    209083.5      안심지역
# 충청북도 흥덕구  6.990770    262632.0      안심지역
#
# [223 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='darkgrid')

sns.scatterplot(x='total_2020', 
                y='2020', 
                hue='인구감소지수 분류', # different colors by group
                style='인구감소지수 분류', # different shapes by group
                s=80, # marker size
                data=birth_rate_g)

plt.title('2020년 조출생률')
plt.xlabel('인구수')
plt.ylabel('조출생률')

plt.savefig('output/birth_rate_2020.png')
plt.show()

# %%
birth_89 = birth_rate[birth_rate['인구감소지수 분류'].isin(['인구감소지역'])]
birth_89
# Out:
#               2016      2017      2018      2019      2020 인구감소지수 분류
# sigungu
# 강원도 고성군   4.921820  4.521856  3.671250  4.620870  3.657877    인구감소지역
# 강원도 삼척시   5.483474  4.928990  5.030500  5.449956  5.455404    인구감소지역
# 강원도 양구군   8.703293  8.453725  6.984965  7.454228  7.104875    인구감소지역
# 강원도 양양군   4.896907  3.516630  4.950586  4.282028  3.221428    인구감소지역
# 강원도 영월군   4.118970  3.593981  3.100618  3.112780  3.207719    인구감소지역
# ...            ...       ...       ...       ...       ...       ...
# 충청북도 단양군  3.699727  3.065645  3.478145  3.200863  2.539203    인구감소지역
# 충청북도 보은군  5.452322  5.143592  5.302353  3.088756  3.456523    인구감소지역
# 충청북도 영동군  4.538488  5.978685  5.746257  4.523961  4.524839    인구감소지역
# 충청북도 옥천군  5.281266  4.051408  3.358916  3.501077  3.513229    인구감소지역
# 충청북도 제천시  6.585853  5.610140  5.594706  5.035397  4.605573    인구감소지역
#
# [89 rows x 6 columns]

# %%
birth_18 = birth_rate[birth_rate['인구감소지수 분류'].isin(['관심지역'])]
birth_18
# Out:
#                 2016      2017      2018      2019      2020 인구감소지수 분류
# sigungu
# 강원도 강릉시     5.818278  5.110098  4.893348  4.559094  4.488691      관심지역
# 강원도 동해시     7.129434  6.076229  5.169006  4.681243  4.498185      관심지역
# 강원도 속초시     6.368564  4.710513  5.120095  5.111174  5.092243      관심지역
# 강원도 인제군    10.217620  9.550069  8.143854  8.039219  7.047172      관심지역
# 경기도 동두천시    7.433319  6.098901  4.905251  4.557953  4.244771      관심지역
# 경기도 포천시     6.410445  5.748523  5.140344  4.170737  3.978413      관심지역
# 경상남도 사천시    7.625935  6.494678  5.390240  4.436411  4.725356      관심지역
# 경상남도 통영시    7.696501  6.215589  4.791305  4.072855  3.629806      관심지역
# 경상북도 경주시    6.312734  5.311361  4.895659  4.373012  4.365507      관심지역
# 경상북도 김천시    8.000883  7.519513  7.202218  6.255321  6.009500      관심지역
# 광주광역시 동구    5.846149  5.576663  4.929144  4.837613  4.972866      관심지역
# 대전광역시 대덕구   7.060923  5.933694  5.116430  4.572640  3.994382      관심지역
# ...

# %%
birth_non = birth_rate[birth_rate['인구감소지수 분류'].isin(['안심지역'])]
birth_non
# Out:
#                2016       2017       2018      2019      2020 인구감소지수 분류
# sigungu
# 강원도 원주시    7.410755   6.794339   5.998469  6.235082  5.942277      안심지역
# 강원도 춘천시    7.194790   6.260006   6.127044  6.010909  5.690907      안심지역
# 경기도 과천시    6.313189   5.306683   4.940095  4.919577  6.561976      안심지역
# 경기도 광명시    8.570674   7.132085   6.500515  5.736480  5.474890      안심지역
# 경기도 광주시    9.570837   8.493521   8.018289  7.276196  6.509707      안심지역
# ...             ...        ...        ...       ...       ...       ...
# 충청북도 증평군  10.921390   9.823998   8.673886  7.214289  5.393977      안심지역
# 충청북도 진천군   7.787104   7.195456   7.223758  7.818174  6.405759      안심지역
# 충청북도 청원구  13.003985  10.995698  10.582772  8.717870  7.536447      안심지역
# 충청북도 충주시   6.905740   5.963888   5.552925  5.257360  4.983655      안심지역
# 충청북도 흥덕구   9.527890   8.837213   8.083358  7.125017  6.990770      안심지역
#
# [116 rows x 6 columns]

# %%
birth_mean = pd.DataFrame({'인구감소지역':birth_89.mean()})
birth_mean['관심지역']=birth_18.mean()
birth_mean['안심지역']=birth_non.mean()
birth_mean['전국']=birth_rate.mean()
birth_mean
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_1507/736246386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   birth_mean = pd.DataFrame({'인구감소지역':birth_89.mean()})
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_1507/736246386.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   birth_mean['관심지역']=birth_18.mean()
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_1507/736246386.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# ...

# %%
birth_mean.plot(kind='bar')

plt.title('5년간 조출생률의 변화')

plt.xticks(rotation=0)
plt.xlabel('연도')
plt.ylabel('비율의 평균')
plt.legend(bbox_to_anchor=(1,1))

plt.savefig('output/birth_5years_mean_bar.png')
plt.show()

# %%
plt.style.use('ggplot')
fig=plt.figure(figsize=(8,5))
ax=fig.add_subplot(1,1,1)

ax.plot(birth_mean['인구감소지역'],marker='o',markerfacecolor='#ff5050',markersize=8,color='#ff5050',label='인구감소지역')
ax.plot(birth_mean['관심지역'],marker='o',markerfacecolor='orange',markersize=8,color='orange',label='관심지역')
ax.plot(birth_mean['안심지역'],marker='o',markerfacecolor='#00ccff',markersize=8,color='#00ccff',label='안심지역')
#ax.plot(birth_mean['전국'],marker='o',markerfacecolor='indigo',markersize=8,color='skyblue',label='전국')

ax.legend(loc='best')

ax.set_title('5년간 조출생률의 변화')

ax.set_ylabel('조출생률의 평균')
ax.set_xlabel('연도')


plt.savefig('output/birth_5years_mean_line.png')
plt.show()

# %%
sido_89 = pd.read_csv('../total_pop/sido.csv')
sido_89.set_index('sigungu', inplace=True)
sido_89.sort_index(inplace=True)
sido_89
# Out:
#           sido
# sigungu
# 강원도 고성군    강원도
# 강원도 삼척시    강원도
# 강원도 양구군    강원도
# 강원도 양양군    강원도
# 강원도 영월군    강원도
# ...        ...
# 충청북도 단양군  충청북도
# 충청북도 보은군  충청북도
# 충청북도 영동군  충청북도
# 충청북도 옥천군  충청북도
# 충청북도 제천시  충청북도
#
# [89 rows x 1 columns]

# %%
pop_89=pd.read_csv('../total_pop/pop_89.csv')
pop_89.rename(columns={'행정구역(시군구)별':'sigungu'}, inplace=True)
pop_89.set_index('sigungu',inplace=True)
pop_89.sort_index(inplace=True)
pop_89
# Out:
#           total_2016  total_2017  total_2018  total_2019  total_2020
# sigungu
# 강원도 고성군      29867.0     29855.0     28873.0     27484.0     26791.5
# 강원도 삼척시      69481.5     68371.0     67786.5     67156.5     65623.0
# 강원도 양구군      23899.0     23776.5     23479.0     22940.0     22379.0
# 강원도 양양군      27160.0     27014.5     27067.5     27323.5     27627.5
# 강원도 영월군      39573.0     39510.5     39347.0     38872.0     38345.0
# ...              ...         ...         ...         ...         ...
# 충청북도 단양군     30272.5     30010.0     29901.0     29679.5     29143.0
# 충청북도 보은군     33930.5     33828.5     33570.0     33023.0     32402.5
# 충청북도 영동군     50237.0     50011.0     49597.5     48851.0     47736.5
# 충청북도 옥천군     51881.5     51587.0     51207.0     50841.5     50381.0
# 충청북도 제천시    135290.0    135469.0    134949.0    134051.0    132882.5
#
# [89 rows x 5 columns]

# %%
birth_89['sido']=sido_89['sido']
birth_89['pop']=pop_89['total_2020']
birth_89
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_1507/1840508574.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   birth_89['sido']=sido_89['sido']
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_1507/1840508574.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   birth_89['pop']=pop_89['total_2020']
#               2016      2017      2018      2019      2020 인구감소지수 분류  sido  \
# sigungu
# 강원도 고성군   4.921820  4.521856  3.671250  4.620870  3.657877    인구감소지역   강원도
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

sns.scatterplot(x='pop', y='2020', hue='sido',style='sido',s=60,data=birth_89)

plt.title('인구감소지역 조출산율')
plt.xlabel('인구수')
plt.ylabel('조출산율')
plt.legend(fontsize=6)
plt.savefig('output/birth_rate_89_sido.png', bbox_inches='tight')
plt.show()

# %%
import numpy as np

count, bin_dividers = np.histogram(birth_89['2020'],bins=4)
bin_dividers
# Out:
# array([ 2.00164237,  4.13479795,  6.26795353,  8.4011091 , 10.53426468])

# %%
bin_names=['2~4','4.1~6','6.2~8','8.4~10.6']

birth_89['hp_bin']=pd.cut(x=birth_89['2020'],bins=bin_dividers,labels=bin_names,include_lowest=True)
birth_89
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_1507/787684176.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   birth_89['hp_bin']=pd.cut(x=birth_89['2020'],bins=bin_dividers,labels=bin_names,include_lowest=True)
#               2016      2017      2018      2019      2020 인구감소지수 분류  sido  \
# sigungu
# 강원도 고성군   4.921820  4.521856  3.671250  4.620870  3.657877    인구감소지역   강원도
# 강원도 삼척시   5.483474  4.928990  5.030500  5.449956  5.455404    인구감소지역   강원도
# 강원도 양구군   8.703293  8.453725  6.984965  7.454228  7.104875    인구감소지역   강원도
# 강원도 양양군   4.896907  3.516630  4.950586  4.282028  3.221428    인구감소지역   강원도
# 강원도 영월군   4.118970  3.593981  3.100618  3.112780  3.207719    인구감소지역   강원도
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import rc
import seaborn as sns

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='whitegrid')

sns.scatterplot(x='pop', y='2020', hue='hp_bin',style='hp_bin',s=60,data=birth_89)

plt.title('인구감소지역 조출산율')
plt.xlabel('인구수')
plt.ylabel('조출산율')
plt.legend(fontsize=6)
plt.savefig('output/birth_rate_89_bins.png', bbox_inches='tight')
plt.show()

# %%
sig_cd = pd.read_csv('../total_pop/sig_cd.csv')
sig_cd.set_index('sigungu', inplace=True)
sig_cd.sort_index(inplace=True)
sig_cd
# Out:
#           SIG_CD SIG_KOR_NM
# sigungu
# 강원도 고성군    42820        고성군
# 강원도 삼척시    42230        삼척시
# 강원도 양구군    42800        양구군
# 강원도 양양군    42830        양양군
# 강원도 영월군    42750        영월군
# ...          ...        ...
# 충청북도 단양군   43800        단양군
# 충청북도 보은군   43720        보은군
# 충청북도 영동군   43740        영동군
# 충청북도 옥천군   43730        옥천군
# 충청북도 제천시   43150        제천시
#
# [89 rows x 2 columns]

# %%
birth_89['sig_cd']=sig_cd['SIG_CD']
birth_89
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_1507/2992525399.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   birth_89['sig_cd']=sig_cd['SIG_CD']
#               2016      2017      2018      2019      2020 인구감소지수 분류  sido  \
# sigungu
# 강원도 고성군   4.921820  4.521856  3.671250  4.620870  3.657877    인구감소지역   강원도
# 강원도 삼척시   5.483474  4.928990  5.030500  5.449956  5.455404    인구감소지역   강원도
# 강원도 양구군   8.703293  8.453725  6.984965  7.454228  7.104875    인구감소지역   강원도
# 강원도 양양군   4.896907  3.516630  4.950586  4.282028  3.221428    인구감소지역   강원도
# 강원도 영월군   4.118970  3.593981  3.100618  3.112780  3.207719    인구감소지역   강원도
# ...            ...       ...       ...       ...       ...       ...   ...
# ...

# %%
birth_89.to_csv('birth_89_result.csv')

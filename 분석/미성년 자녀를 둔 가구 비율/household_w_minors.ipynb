# %% [markdown]
# ## 미성년 자녀를 둔 가구 비율
# - 자료 출처
# <br><t>통계청,「인구총조사」, 2021, 2022.12.22, 가구형태별 가구 및 가구원 - 읍면동(연도 끝자리 0,5), 시군구(그 외 연도)
# <br><t>통계청,「인구총조사」, 2021, 2022.12.21, 미성년자가 있는 자녀수별 가구 - 시군구

# %%
import pandas as pd

hwm_hh=pd.read_csv('./household_w_minors.csv')
total_hh=pd.read_csv('../total_household/total_household.csv')
hwm_hh
# Out:
#        행정구역별(시군구)  sum_2016  1자녀_2016  2자녀_2016  3자녀_2016  4자녀_2016  \
# 0      부산광역시 > 중구      3007      1398      1346       229      29.0
# 1      부산광역시 > 서구      8380      3591      3985       726      68.0
# 2      부산광역시 > 동구      6238      2643      2984       550      44.0
# 3     부산광역시 > 영도구      9565      3937      4692       859      66.0
# 4    부산광역시 > 부산진구     33279     13739     16717      2627     174.0
# ..            ...       ...       ...       ...       ...       ...
# 217    경상남도 > 하동군      3081      1244      1377       402      53.0
# 218    경상남도 > 산청군      2252       973       943       286      37.0
# 219    경상남도 > 함양군      2874      1160      1249       399      52.0
# 220    경상남도 > 거창군      5638      2006      2746       800      69.0
# 221    경상남도 > 합천군      2684      1128      1149       352      44.0
#
#      5자녀+_2016  sum_2017  1자녀_2017  2자녀_2017  ...  2자녀_2019  3자녀_2019  \
# 0          5.0      2705      1286      1187  ...       909       164
# ...

# %%
total_hh
# Out:
#        행정구역별(읍면동)  총가구_2016  일반가구_2016  집단가구_비혈연_2016  집단가구_집단시설_2016  \
# 0      부산광역시 > 중구     20923      20468            5.0            15.0
# 1      부산광역시 > 서구     46808      46391           11.0            30.0
# 2      부산광역시 > 동구     37981      37308           11.0            13.0
# 3     부산광역시 > 영도구     52345      51910            7.0            19.0
# 4    부산광역시 > 부산진구    152729     151910           15.0            33.0
# ..            ...       ...        ...            ...             ...
# 217    경상남도 > 하동군     19389      19208            6.0            14.0
# 218    경상남도 > 산청군     15254      15044            5.0            17.0
# 219    경상남도 > 함양군     16920      16780            NaN            16.0
# 220    경상남도 > 거창군     25143      24958            NaN            19.0
# 221    경상남도 > 합천군     20503      20313            NaN            16.0
#
#      외국인가구_2016  총가구_2017  일반가구_2017  집단가구_비혈연_2017  집단가구_집단시설_2017  ...  \
# ...

# %%
hwm_hh.rename(columns={'행정구역별(시군구)':'sigungu'}, inplace=True)
hwm_hh.set_index('sigungu', inplace=True)
hwm_hh.sort_index(inplace=True)
hwm_hh
# Out:
#             sum_2016  1자녀_2016  2자녀_2016  3자녀_2016  4자녀_2016  5자녀+_2016  \
# sigungu
# 강원도 > 강릉시      21567      8880     10629      1881     152.0       25.0
# 강원도 > 고성군       1911       878       812       202      14.0        5.0
# 강원도 > 동해시      10128      4045      4935      1032     105.0       11.0
# 강원도 > 삼척시       5757      2428      2671       603      45.0       10.0
# 강원도 > 속초시       8879      3887      4219       708      61.0        NaN
# ...              ...       ...       ...       ...       ...        ...
# 충청북도 > 증평군      4241      1586      2010       586      48.0       11.0
# 충청북도 > 진천군      7244      2640      3542       949      90.0       23.0
# 충청북도 > 청원구     24164      8961     12349      2600     219.0       35.0
# 충청북도 > 충주시     20913      8321     10194      2181     191.0       26.0
# 충청북도 > 흥덕구     30484     10983     15661      3523     278.0       39.0
#
#             sum_2017  1자녀_2017  2자녀_2017  3자녀_2017  ...  2자녀_2019  3자녀_2019  \
# ...

# %%
hwm_hh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 222 entries, 강원도 > 강릉시 to 충청북도 > 흥덕구
# Data columns (total 30 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sum_2016   222 non-null    int64
#  1   1자녀_2016   222 non-null    int64
#  2   2자녀_2016   222 non-null    int64
#  3   3자녀_2016   222 non-null    int64
#  4   4자녀_2016   221 non-null    float64
#  5   5자녀+_2016  209 non-null    float64
#  6   sum_2017   222 non-null    int64
#  7   1자녀_2017   222 non-null    int64
#  8   2자녀_2017   222 non-null    int64
#  9   3자녀_2017   222 non-null    int64
#  10  4자녀_2017   222 non-null    int64
#  11  5자녀+_2017  207 non-null    float64
#  12  sum_2018   222 non-null    int64
#  13  1자녀_2018   222 non-null    int64
#  14  2자녀_2018   222 non-null    int64
#  15  3자녀_2018   222 non-null    int64
#  16  4자녀_2018   221 non-null    float64
#  17  5자녀+_2018  207 non-null    float64
#  18  sum_2019   222 non-null    int64
# ...

# %%
hwm_hh.isnull().sum()
# Out:
# sum_2016      0
# 1자녀_2016      0
# 2자녀_2016      0
# 3자녀_2016      0
# 4자녀_2016      1
# 5자녀+_2016    13
# sum_2017      0
# 1자녀_2017      0
# 2자녀_2017      0
# 3자녀_2017      0
# 4자녀_2017      0
# 5자녀+_2017    15
# sum_2018      0
# 1자녀_2018      0
# 2자녀_2018      0
# 3자녀_2018      0
# 4자녀_2018      1
# 5자녀+_2018    15
# sum_2019      0
# 1자녀_2019      0
# 2자녀_2019      0
# 3자녀_2019      0
# 4자녀_2019      1
# 5자녀+_2019    22
# sum_2020      0
# 1자녀_2020      0
# 2자녀_2020      0
# 3자녀_2020      0
# 4자녀_2020      0
# 5자녀+_2020    22
# dtype: int64

# %%
hwm_hh['4자녀_2016'].fillna(hwm_hh['4자녀_2016'].mean(axis=0),inplace=True)
hwm_hh['5자녀+_2016'].fillna(hwm_hh['5자녀+_2016'].mean(axis=0),inplace=True)
hwm_hh['5자녀+_2017'].fillna(hwm_hh['5자녀+_2017'].mean(axis=0),inplace=True)
hwm_hh['4자녀_2018'].fillna(hwm_hh['4자녀_2018'].mean(axis=0),inplace=True)
hwm_hh['5자녀+_2018'].fillna(hwm_hh['5자녀+_2018'].mean(axis=0),inplace=True)
hwm_hh['4자녀_2019'].fillna(hwm_hh['4자녀_2019'].mean(axis=0),inplace=True)
hwm_hh['5자녀+_2019'].fillna(hwm_hh['5자녀+_2019'].mean(axis=0),inplace=True)
hwm_hh['5자녀+_2020'].fillna(hwm_hh['5자녀+_2020'].mean(axis=0),inplace=True)
hwm_hh.isnull().sum()
# Out:
# sum_2016     0
# 1자녀_2016     0
# 2자녀_2016     0
# 3자녀_2016     0
# 4자녀_2016     0
# 5자녀+_2016    0
# sum_2017     0
# 1자녀_2017     0
# 2자녀_2017     0
# 3자녀_2017     0
# 4자녀_2017     0
# 5자녀+_2017    0
# sum_2018     0
# 1자녀_2018     0
# 2자녀_2018     0
# 3자녀_2018     0
# 4자녀_2018     0
# 5자녀+_2018    0
# sum_2019     0
# 1자녀_2019     0
# 2자녀_2019     0
# 3자녀_2019     0
# 4자녀_2019     0
# 5자녀+_2019    0
# sum_2020     0
# 1자녀_2020     0
# 2자녀_2020     0
# 3자녀_2020     0
# 4자녀_2020     0
# 5자녀+_2020    0
# dtype: int64

# %%
hwm_hh['3자녀+_2016']=hwm_hh['3자녀_2016']+hwm_hh['4자녀_2016']+hwm_hh['5자녀+_2016']
hwm_hh
# Out:
#             sum_2016  1자녀_2016  2자녀_2016  3자녀_2016  4자녀_2016  5자녀+_2016  \
# sigungu
# 강원도 > 강릉시      21567      8880     10629      1881     152.0  25.000000
# 강원도 > 고성군       1911       878       812       202      14.0   5.000000
# 강원도 > 동해시      10128      4045      4935      1032     105.0  11.000000
# 강원도 > 삼척시       5757      2428      2671       603      45.0  10.000000
# 강원도 > 속초시       8879      3887      4219       708      61.0  24.148325
# ...              ...       ...       ...       ...       ...        ...
# 충청북도 > 증평군      4241      1586      2010       586      48.0  11.000000
# 충청북도 > 진천군      7244      2640      3542       949      90.0  23.000000
# 충청북도 > 청원구     24164      8961     12349      2600     219.0  35.000000
# 충청북도 > 충주시     20913      8321     10194      2181     191.0  26.000000
# 충청북도 > 흥덕구     30484     10983     15661      3523     278.0  39.000000
#
#             sum_2017  1자녀_2017  2자녀_2017  3자녀_2017  ...  3자녀_2019  4자녀_2019  \
# ...

# %%
hwm_hh['3자녀+_2017']=hwm_hh['3자녀_2017']+hwm_hh['4자녀_2017']+hwm_hh['5자녀+_2017']
hwm_hh
# Out:
#             sum_2016  1자녀_2016  2자녀_2016  3자녀_2016  4자녀_2016  5자녀+_2016  \
# sigungu
# 강원도 > 강릉시      21567      8880     10629      1881     152.0  25.000000
# 강원도 > 고성군       1911       878       812       202      14.0   5.000000
# 강원도 > 동해시      10128      4045      4935      1032     105.0  11.000000
# 강원도 > 삼척시       5757      2428      2671       603      45.0  10.000000
# 강원도 > 속초시       8879      3887      4219       708      61.0  24.148325
# ...              ...       ...       ...       ...       ...        ...
# 충청북도 > 증평군      4241      1586      2010       586      48.0  11.000000
# 충청북도 > 진천군      7244      2640      3542       949      90.0  23.000000
# 충청북도 > 청원구     24164      8961     12349      2600     219.0  35.000000
# 충청북도 > 충주시     20913      8321     10194      2181     191.0  26.000000
# 충청북도 > 흥덕구     30484     10983     15661      3523     278.0  39.000000
#
#             sum_2017  1자녀_2017  2자녀_2017  3자녀_2017  ...  4자녀_2019  5자녀+_2019  \
# ...

# %%
hwm_hh['3자녀+_2018']=hwm_hh['3자녀_2018']+hwm_hh['4자녀_2018']+hwm_hh['5자녀+_2018']
hwm_hh
# Out:
#             sum_2016  1자녀_2016  2자녀_2016  3자녀_2016  4자녀_2016  5자녀+_2016  \
# sigungu
# 강원도 > 강릉시      21567      8880     10629      1881     152.0  25.000000
# 강원도 > 고성군       1911       878       812       202      14.0   5.000000
# 강원도 > 동해시      10128      4045      4935      1032     105.0  11.000000
# 강원도 > 삼척시       5757      2428      2671       603      45.0  10.000000
# 강원도 > 속초시       8879      3887      4219       708      61.0  24.148325
# ...              ...       ...       ...       ...       ...        ...
# 충청북도 > 증평군      4241      1586      2010       586      48.0  11.000000
# 충청북도 > 진천군      7244      2640      3542       949      90.0  23.000000
# 충청북도 > 청원구     24164      8961     12349      2600     219.0  35.000000
# 충청북도 > 충주시     20913      8321     10194      2181     191.0  26.000000
# 충청북도 > 흥덕구     30484     10983     15661      3523     278.0  39.000000
#
#             sum_2017  1자녀_2017  2자녀_2017  3자녀_2017  ...  5자녀+_2019  sum_2020  \
# ...

# %%
hwm_hh['3자녀+_2019']=hwm_hh['3자녀_2019']+hwm_hh['4자녀_2019']+hwm_hh['5자녀+_2019']
hwm_hh
# Out:
#             sum_2016  1자녀_2016  2자녀_2016  3자녀_2016  4자녀_2016  5자녀+_2016  \
# sigungu
# 강원도 > 강릉시      21567      8880     10629      1881     152.0  25.000000
# 강원도 > 고성군       1911       878       812       202      14.0   5.000000
# 강원도 > 동해시      10128      4045      4935      1032     105.0  11.000000
# 강원도 > 삼척시       5757      2428      2671       603      45.0  10.000000
# 강원도 > 속초시       8879      3887      4219       708      61.0  24.148325
# ...              ...       ...       ...       ...       ...        ...
# 충청북도 > 증평군      4241      1586      2010       586      48.0  11.000000
# 충청북도 > 진천군      7244      2640      3542       949      90.0  23.000000
# 충청북도 > 청원구     24164      8961     12349      2600     219.0  35.000000
# 충청북도 > 충주시     20913      8321     10194      2181     191.0  26.000000
# 충청북도 > 흥덕구     30484     10983     15661      3523     278.0  39.000000
#
#             sum_2017  1자녀_2017  2자녀_2017  3자녀_2017  ...  sum_2020  1자녀_2020  \
# ...

# %%
hwm_hh['3자녀+_2020']=hwm_hh['3자녀_2020']+hwm_hh['4자녀_2020']+hwm_hh['5자녀+_2020']
hwm_hh
# Out:
#             sum_2016  1자녀_2016  2자녀_2016  3자녀_2016  4자녀_2016  5자녀+_2016  \
# sigungu
# 강원도 > 강릉시      21567      8880     10629      1881     152.0  25.000000
# 강원도 > 고성군       1911       878       812       202      14.0   5.000000
# 강원도 > 동해시      10128      4045      4935      1032     105.0  11.000000
# 강원도 > 삼척시       5757      2428      2671       603      45.0  10.000000
# 강원도 > 속초시       8879      3887      4219       708      61.0  24.148325
# ...              ...       ...       ...       ...       ...        ...
# 충청북도 > 증평군      4241      1586      2010       586      48.0  11.000000
# 충청북도 > 진천군      7244      2640      3542       949      90.0  23.000000
# 충청북도 > 청원구     24164      8961     12349      2600     219.0  35.000000
# 충청북도 > 충주시     20913      8321     10194      2181     191.0  26.000000
# 충청북도 > 흥덕구     30484     10983     15661      3523     278.0  39.000000
#
#             sum_2017  1자녀_2017  2자녀_2017  3자녀_2017  ...  1자녀_2020  2자녀_2020  \
# ...

# %%
hwm_sum=hwm_hh[['sum_2016','sum_2017','sum_2018','sum_2019','sum_2020']]
hwm_sum.rename(columns={'sum_2016':'2016',
               'sum_2017':'2017',
               'sum_2018':'2018',
               'sum_2019':'2019',
               'sum_2020':'2020'}, inplace=True)
hwm_sum
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_5922/1424546411.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hwm_sum.rename(columns={'sum_2016':'2016',
#              2016   2017   2018   2019   2020
# sigungu
# 강원도 > 강릉시   21567  20651  19885  19012  18405
# 강원도 > 고성군    1911   1901   1758   1646   1566
# 강원도 > 동해시   10128   9727   9300   8814   8638
# 강원도 > 삼척시    5757   5452   5299   5044   4835
# 강원도 > 속초시    8879   8461   8120   7805   7639
# ...           ...    ...    ...    ...    ...
# 충청북도 > 증평군   4241   4196   4001   3799   3628
# 충청북도 > 진천군   7244   7705   8120   8404   8526
# 충청북도 > 청원구  24164  24233  24049  23139  22165
# 충청북도 > 충주시  20913  20243  19840  19014  18643
# 충청북도 > 흥덕구  30484  29518  28388  28305  28244
#
# [222 rows x 5 columns]

# %%
hwm_one=hwm_hh[['1자녀_2016','1자녀_2017','1자녀_2018','1자녀_2019','1자녀_2020']]
hwm_one.rename(columns={'1자녀_2016':'2016',
               '1자녀_2017':'2017',
               '1자녀_2018':'2018',
               '1자녀_2019':'2019',
               '1자녀_2020':'2020'}, inplace=True)
hwm_one
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_5922/2547689692.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hwm_one.rename(columns={'1자녀_2016':'2016',
#              2016   2017   2018   2019   2020
# sigungu
# 강원도 > 강릉시    8880   8718   8567   8188   7905
# 강원도 > 고성군     878    867    820    766    720
# 강원도 > 동해시    4045   3947   3818   3600   3528
# 강원도 > 삼척시    2428   2345   2311   2199   2061
# 강원도 > 속초시    3887   3793   3711   3502   3397
# ...           ...    ...    ...    ...    ...
# 충청북도 > 증평군   1586   1593   1504   1460   1390
# 충청북도 > 진천군   2640   2912   3143   3339   3348
# 충청북도 > 청원구   8961   9146   9160   9004   8377
# 충청북도 > 충주시   8321   8184   8271   7946   7592
# 충청북도 > 흥덕구  10983  10714  10502  10873  10863
#
# [222 rows x 5 columns]

# %%
hwm_two=hwm_hh[['2자녀_2016','2자녀_2017','2자녀_2018','2자녀_2019','2자녀_2020']]
hwm_two.rename(columns={'2자녀_2016':'2016',
               '2자녀_2017':'2017',
               '2자녀_2018':'2018',
               '2자녀_2019':'2019',
               '2자녀_2020':'2020'}, inplace=True)
hwm_two
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_5922/3375398572.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hwm_two.rename(columns={'2자녀_2016':'2016',
#              2016   2017   2018   2019   2020
# sigungu
# 강원도 > 강릉시   10629   9961   9456   9017   8709
# 강원도 > 고성군     812    810    741    705    661
# 강원도 > 동해시    4935   4663   4402   4226   4109
# 강원도 > 삼척시    2671   2508   2395   2281   2227
# 강원도 > 속초시    4219   3905   3693   3573   3497
# ...           ...    ...    ...    ...    ...
# 충청북도 > 증평군   2010   1970   1889   1771   1696
# 충청북도 > 진천군   3542   3694   3848   3979   4076
# 충청북도 > 청원구  12349  12269  12097  11524  11185
# 충청북도 > 충주시  10194   9787   9389   8961   8950
# 충청북도 > 흥덕구  15661  15091  14323  14053  14017
#
# [222 rows x 5 columns]

# %%
hwm_three=hwm_hh[['3자녀+_2016','3자녀+_2017','3자녀+_2018','3자녀+_2019','3자녀+_2020']]
hwm_three.rename(columns={'3자녀+_2016':'2016',
               '3자녀+_2017':'2017',
               '3자녀+_2018':'2018',
               '3자녀+_2019':'2019',
               '3자녀+_2020':'2020'}, inplace=True)
hwm_three
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_5922/1939540582.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hwm_three.rename(columns={'3자녀+_2016':'2016',
#                    2016    2017        2018     2019      2020
# sigungu
# 강원도 > 강릉시   2058.000000  1972.0  1862.00000  1807.00  1791.000
# 강원도 > 고성군    221.000000   224.0   218.31401   194.85   203.675
# 강원도 > 동해시   1148.000000  1117.0  1080.00000   988.00  1001.000
# 강원도 > 삼척시    658.000000   599.0   593.00000   564.00   547.000
# 강원도 > 속초시    793.148325   763.0   716.00000   748.85   745.000
# ...                 ...     ...         ...      ...       ...
# 충청북도 > 증평군   645.000000   633.0   608.00000   568.00   542.000
# 충청북도 > 진천군  1062.000000  1099.0  1129.00000  1086.00  1102.000
# ...

# %%
total_hh.rename(columns={'행정구역별(읍면동)':'sigungu',
                           'total_2016':'2016',
                           'total_2017':'2017',
                           'total_2018':'2018',
                           'total_2019':'2019',
                           'total_2020':'2020'}, inplace=True)
total_hh.set_index('sigungu', inplace=True)
total_hh.sort_index(inplace=True)
total_hh
# Out:
#             총가구_2016  일반가구_2016  집단가구_비혈연_2016  집단가구_집단시설_2016  외국인가구_2016  \
# sigungu
# 강원도 > 강릉시      89302      88622           14.0            66.0         600
# 강원도 > 고성군      13104      12982            NaN            13.0         105
# 강원도 > 동해시      36237      35990            6.0            10.0         231
# 강원도 > 삼척시      29453      29243            9.0            18.0         183
# 강원도 > 속초시      33123      32809            9.0            16.0         289
# ...              ...        ...            ...             ...         ...
# 충청북도 > 증평군     14843      14557            NaN            12.0         272
# 충청북도 > 진천군     28651      26817           12.0            51.0        1771
# 충청북도 > 청원구     73871      72501           11.0            34.0        1325
# 충청북도 > 충주시     86707      85152           16.0            65.0        1474
# 충청북도 > 흥덕구     99178      97008            6.0            34.0        2130
#
# ...

# %%
total_hh=total_hh[['총가구_2016','총가구_2017','총가구_2018','총가구_2019','총가구_2020']]
total_hh.rename(columns={'총가구_2016':'2016',
               '총가구_2017':'2017',
               '총가구_2018':'2018',
               '총가구_2019':'2019',
               '총가구_2020':'2020'}, inplace=True)
total_hh
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_5922/2305418351.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total_hh.rename(columns={'총가구_2016':'2016',
#              2016    2017    2018    2019    2020
# sigungu
# 강원도 > 강릉시   89302   90627   91378   93078   99109
# 강원도 > 고성군   13104   12352   12188   11292   12096
# 강원도 > 동해시   36237   36218   36358   36613   37871
# 강원도 > 삼척시   29453   29072   29712   29615   31016
# 강원도 > 속초시   33123   33441   33961   34550   35922
# ...           ...     ...     ...     ...     ...
# 충청북도 > 증평군  14843   15207   15446   15726   16090
# 충청북도 > 진천군  28651   31219   33339   35362   37427
# 충청북도 > 청원구  73871   76101   79192   81234   82572
# 충청북도 > 충주시  86707   88079   90559   92220   95281
# 충청북도 > 흥덕구  99178  102083  103269  108024  113965
# ...

# %%
total_hh.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 222 entries, 강원도 > 강릉시 to 충청북도 > 흥덕구
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   2016    222 non-null    int64
#  1   2017    222 non-null    int64
#  2   2018    222 non-null    int64
#  3   2019    222 non-null    int64
#  4   2020    222 non-null    int64
# dtypes: int64(5)
# memory usage: 10.4+ KB

# %%
hwm_rate=hwm_sum/total_hh*100
hwm_rate['인구감소지수 분류']='안심지역'
hwm_rate
# Out:
#                  2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 > 강릉시   24.150635  22.786807  21.761255  20.425879  18.570463      안심지역
# 강원도 > 고성군   14.583333  15.390220  14.424024  14.576691  12.946429      안심지역
# 강원도 > 동해시   27.949334  26.856812  25.578965  24.073417  22.809010      안심지역
# 강원도 > 삼척시   19.546396  18.753440  17.834545  17.031910  15.588728      안심지역
# 강원도 > 속초시   26.806147  25.301277  23.909779  22.590449  21.265520      안심지역
# ...               ...        ...        ...        ...        ...       ...
# 충청북도 > 증평군  28.572391  27.592556  25.903146  24.157446  22.548167      안심지역
# 충청북도 > 진천군  25.283585  24.680483  24.355860  23.765624  22.780346      안심지역
# 충청북도 > 청원구  32.711077  31.843208  30.367966  28.484378  26.843240      안심지역
# 충청북도 > 충주시  24.119160  22.982777  21.908369  20.618087  19.566335      안심지역
# 충청북도 > 흥덕구  30.736655  28.915686  27.489372  26.202511  24.783047      안심지역
#
# [222 rows x 6 columns]

# %%
hwm_rate1=hwm_one/total_hh*100
hwm_rate1['인구감소지수 분류']='안심지역'
hwm_rate1
# Out:
#                  2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 > 강릉시    9.943786   9.619650   9.375342   8.796923   7.976067      안심지역
# 강원도 > 고성군    6.700244   7.019106   6.727929   6.783564   5.952381      안심지역
# 강원도 > 동해시   11.162624  10.897896  10.501128   9.832573   9.315835      안심지역
# 강원도 > 삼척시    8.243642   8.066181   7.778002   7.425291   6.644957      안심지역
# 강원도 > 속초시   11.735048  11.342364  10.927240  10.136035   9.456600      안심지역
# ...               ...        ...        ...        ...        ...       ...
# 충청북도 > 증평군  10.685171  10.475439   9.737149   9.283988   8.638906      안심지역
# 충청북도 > 진천군   9.214338   9.327653   9.427397   9.442339   8.945414      안심지역
# 충청북도 > 청원구  12.130606  12.018239  11.566825  11.084029  10.145086      안심지역
# 충청북도 > 충주시   9.596688   9.291659   9.133272   8.616352   7.968010      안심지역
# 충청북도 > 흥덕구  11.074029  10.495381  10.169557  10.065356   9.531874      안심지역
#
# [222 rows x 6 columns]

# %%
hwm_rate2=hwm_two/total_hh*100
hwm_rate2['인구감소지수 분류']='안심지역'
hwm_rate2
# Out:
#                  2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 > 강릉시   11.902309  10.991206  10.348224   9.687574   8.787295      안심지역
# 강원도 > 고성군    6.196581   6.557642   6.079751   6.243358   5.464616      안심지역
# 강원도 > 동해시   13.618677  12.874814  12.107377  11.542348  10.849991      안심지역
# 강원도 > 삼척시    9.068686   8.626857   8.060716   7.702178   7.180165      안심지역
# 강원도 > 속초시   12.737373  11.677282  10.874238  10.341534   9.734981      안심지역
# ...               ...        ...        ...        ...        ...       ...
# 충청북도 > 증평군  13.541737  12.954560  12.229703  11.261605  10.540709      안심지역
# 충청북도 > 진천군  12.362570  11.832538  11.542038  11.252192  10.890534      안심지역
# 충청북도 > 청원구  16.716980  16.121996  15.275533  14.186178  13.545754      안심지역
# 충청북도 > 충주시  11.756836  11.111616  10.367826   9.716981   9.393268      안심지역
# 충청북도 > 흥덕구  15.790800  14.783069  13.869603  13.009146  12.299390      안심지역
#
# [222 rows x 6 columns]

# %%
hwm_rate3=hwm_three/total_hh*100
hwm_rate3['인구감소지수 분류']='안심지역'
hwm_rate3
# Out:
#                 2016      2017      2018      2019      2020 인구감소지수 분류
# sigungu
# 강원도 > 강릉시   2.304540  2.175952  2.037690  1.941382  1.807101      안심지역
# 강원도 > 고성군   1.686508  1.813472  1.791221  1.725558  1.683821      안심지역
# 강원도 > 동해시   3.168033  3.084102  2.970460  2.698495  2.643183      안심지역
# 강원도 > 삼척시   2.234068  2.060402  1.995827  1.904440  1.763606      안심지역
# 강원도 > 속초시   2.394555  2.281630  2.108301  2.167438  2.073938      안심지역
# ...              ...       ...       ...       ...       ...       ...
# 충청북도 > 증평군  4.345483  4.162557  3.936294  3.611853  3.368552      안심지역
# 충청북도 > 진천군  3.706677  3.520292  3.386424  3.071093  2.944398      안심지역
# 충청북도 > 청원구  3.863492  3.702974  3.525609  3.214171  3.152400      안심지역
# 충청북도 > 충주시  2.765636  2.579502  2.407270  2.284754  2.205057      안심지역
# 충청북도 > 흥덕구  3.871826  3.637236  3.450213  3.128009  2.951783      안심지역
#
# [222 rows x 6 columns]

# %%
ingu_89 = ['부산광역시 > 동구', '부산광역시 > 서구', '부산광역시 > 영도구', '대구광역시 > 남구', '대구광역시 > 서구',
           '인천광역시 > 강화군', '인천광역시 > 옹진군', '경기도 > 가평군', '경기도 > 연천군', '강원도 > 고성군', '강원도 > 삼척시',
          '강원도 > 양구군', '강원도 > 양양군', '강원도 > 영월군', '강원도 > 정선군', '강원도 > 철원군', '강원도 > 태백시',
          '강원도 > 평창군', '강원도 > 홍천군', '강원도 > 화천군', '강원도 > 횡성군', '충청북도 > 괴산군', '충청북도 > 단양군',
          '충청북도 > 보은군', '충청북도 > 영동군', '충청북도 > 옥천군', '충청북도 > 제천시', '충청남도 > 공주시', '충청남도 > 금산군',
          '충청남도 > 논산시', '충청남도 > 보령시', '충청남도 > 부여군', '충청남도 > 서천군', '충청남도 > 예산군', '충청남도 > 청양군',
          '충청남도 > 태안군', '전라북도 > 고창군', '전라북도 > 김제시', '전라북도 > 남원시', '전라북도 > 무주군', '전라북도 > 부안군',
          '전라북도 > 순창군', '전라북도 > 임실군', '전라북도 > 장수군', '전라북도 > 정읍시', '전라북도 > 진안군', '전라남도 > 강진군',
          '전라남도 > 고흥군', '전라남도 > 곡성군', '전라남도 > 구례군', '전라남도 > 담양군', '전라남도 > 보성군', '전라남도 > 신안군',
          '전라남도 > 영광군', '전라남도 > 영암군', '전라남도 > 완도군', '전라남도 > 장성군', '전라남도 > 장흥군', '전라남도 > 진도군',
          '전라남도 > 함평군', '전라남도 > 해남군', '전라남도 > 화순군', '경상북도 > 고령군', '경상북도 > 군위군', '경상북도 > 문경시',
          '경상북도 > 봉화군', '경상북도 > 상주시', '경상북도 > 성주군', '경상북도 > 안동시', '경상북도 > 영덕군', '경상북도 > 영양군',
          '경상북도 > 영주시', '경상북도 > 영천시', '경상북도 > 울릉군', '경상북도 > 울진군', '경상북도 > 의성군', '경상북도 > 청도군',
          '경상북도 > 청송군', '경상남도 > 거창군', '경상남도 > 고성군', '경상남도 > 남해군', '경상남도 > 밀양시', '경상남도 > 산청군',
          '경상남도 > 의령군', '경상남도 > 창녕군', '경상남도 > 하동군', '경상남도 > 함안군', '경상남도 > 함양군', '경상남도 > 합천군']

# %%
semi_18 = ['대전광역시 > 동구','인천광역시 > 동구','부산광역시 > 중구','부산광역시 > 금정구','광주광역시 > 동구','경상남도 > 통영시',
           '강원도 > 강릉시','강원도 > 동해시','대전광역시 > 중구','경상북도 > 경주시','경상남도 > 사천시', '경상북도 > 김천시',
          '대전광역시 > 대덕구','강원도 > 인제군','전라북도 > 익산시','경기도 > 동두천시','강원도 > 속초시','경기도 > 포천시']

# %%
for i in ingu_89 :
    hwm_rate.loc[i,'인구감소지수 분류'] = '인구감소지역'
    
for i in semi_18 :
    hwm_rate.loc[i,'인구감소지수 분류'] = '관심지역'

hwm_rate
# Out:
#                  2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 > 강릉시   24.150635  22.786807  21.761255  20.425879  18.570463      관심지역
# 강원도 > 고성군   14.583333  15.390220  14.424024  14.576691  12.946429    인구감소지역
# 강원도 > 동해시   27.949334  26.856812  25.578965  24.073417  22.809010      관심지역
# 강원도 > 삼척시   19.546396  18.753440  17.834545  17.031910  15.588728    인구감소지역
# 강원도 > 속초시   26.806147  25.301277  23.909779  22.590449  21.265520      관심지역
# ...               ...        ...        ...        ...        ...       ...
# 충청북도 > 증평군  28.572391  27.592556  25.903146  24.157446  22.548167      안심지역
# 충청북도 > 진천군  25.283585  24.680483  24.355860  23.765624  22.780346      안심지역
# 충청북도 > 청원구  32.711077  31.843208  30.367966  28.484378  26.843240      안심지역
# 충청북도 > 충주시  24.119160  22.982777  21.908369  20.618087  19.566335      안심지역
# 충청북도 > 흥덕구  30.736655  28.915686  27.489372  26.202511  24.783047      안심지역
#
# [222 rows x 6 columns]

# %%
for i in ingu_89 :
    hwm_rate1.loc[i,'인구감소지수 분류'] = '인구감소지역'
        
for i in semi_18 :
    hwm_rate1.loc[i,'인구감소지수 분류'] = '관심지역'

hwm_rate1
# Out:
#                  2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 > 강릉시    9.943786   9.619650   9.375342   8.796923   7.976067      관심지역
# 강원도 > 고성군    6.700244   7.019106   6.727929   6.783564   5.952381    인구감소지역
# 강원도 > 동해시   11.162624  10.897896  10.501128   9.832573   9.315835      관심지역
# 강원도 > 삼척시    8.243642   8.066181   7.778002   7.425291   6.644957    인구감소지역
# 강원도 > 속초시   11.735048  11.342364  10.927240  10.136035   9.456600      관심지역
# ...               ...        ...        ...        ...        ...       ...
# 충청북도 > 증평군  10.685171  10.475439   9.737149   9.283988   8.638906      안심지역
# 충청북도 > 진천군   9.214338   9.327653   9.427397   9.442339   8.945414      안심지역
# 충청북도 > 청원구  12.130606  12.018239  11.566825  11.084029  10.145086      안심지역
# 충청북도 > 충주시   9.596688   9.291659   9.133272   8.616352   7.968010      안심지역
# 충청북도 > 흥덕구  11.074029  10.495381  10.169557  10.065356   9.531874      안심지역
#
# [222 rows x 6 columns]

# %%
for i in ingu_89 :
    hwm_rate2.loc[i,'인구감소지수 분류'] = '인구감소지역'
        
for i in semi_18 :
    hwm_rate2.loc[i,'인구감소지수 분류'] = '관심지역'

hwm_rate2
# Out:
#                  2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 > 강릉시   11.902309  10.991206  10.348224   9.687574   8.787295      관심지역
# 강원도 > 고성군    6.196581   6.557642   6.079751   6.243358   5.464616    인구감소지역
# 강원도 > 동해시   13.618677  12.874814  12.107377  11.542348  10.849991      관심지역
# 강원도 > 삼척시    9.068686   8.626857   8.060716   7.702178   7.180165    인구감소지역
# 강원도 > 속초시   12.737373  11.677282  10.874238  10.341534   9.734981      관심지역
# ...               ...        ...        ...        ...        ...       ...
# 충청북도 > 증평군  13.541737  12.954560  12.229703  11.261605  10.540709      안심지역
# 충청북도 > 진천군  12.362570  11.832538  11.542038  11.252192  10.890534      안심지역
# 충청북도 > 청원구  16.716980  16.121996  15.275533  14.186178  13.545754      안심지역
# 충청북도 > 충주시  11.756836  11.111616  10.367826   9.716981   9.393268      안심지역
# 충청북도 > 흥덕구  15.790800  14.783069  13.869603  13.009146  12.299390      안심지역
#
# [222 rows x 6 columns]

# %%
for i in ingu_89 :
    hwm_rate3.loc[i,'인구감소지수 분류'] = '인구감소지역'
        
for i in semi_18 :
    hwm_rate3.loc[i,'인구감소지수 분류'] = '관심지역'

hwm_rate3
# Out:
#                 2016      2017      2018      2019      2020 인구감소지수 분류
# sigungu
# 강원도 > 강릉시   2.304540  2.175952  2.037690  1.941382  1.807101      관심지역
# 강원도 > 고성군   1.686508  1.813472  1.791221  1.725558  1.683821    인구감소지역
# 강원도 > 동해시   3.168033  3.084102  2.970460  2.698495  2.643183      관심지역
# 강원도 > 삼척시   2.234068  2.060402  1.995827  1.904440  1.763606    인구감소지역
# 강원도 > 속초시   2.394555  2.281630  2.108301  2.167438  2.073938      관심지역
# ...              ...       ...       ...       ...       ...       ...
# 충청북도 > 증평군  4.345483  4.162557  3.936294  3.611853  3.368552      안심지역
# 충청북도 > 진천군  3.706677  3.520292  3.386424  3.071093  2.944398      안심지역
# 충청북도 > 청원구  3.863492  3.702974  3.525609  3.214171  3.152400      안심지역
# 충청북도 > 충주시  2.765636  2.579502  2.407270  2.284754  2.205057      안심지역
# 충청북도 > 흥덕구  3.871826  3.637236  3.450213  3.128009  2.951783      안심지역
#
# [222 rows x 6 columns]

# %%
hwm_rate_g = pd.DataFrame(hwm_rate['2020'])
hwm_rate_g['total_2020']=total_hh['2020']
hwm_rate_g['인구감소지수 분류']=hwm_rate['인구감소지수 분류']
hwm_rate_g
# Out:
#                  2020  total_2020 인구감소지수 분류
# sigungu
# 강원도 > 강릉시   18.570463       99109      관심지역
# 강원도 > 고성군   12.946429       12096    인구감소지역
# 강원도 > 동해시   22.809010       37871      관심지역
# 강원도 > 삼척시   15.588728       31016    인구감소지역
# 강원도 > 속초시   21.265520       35922      관심지역
# ...               ...         ...       ...
# 충청북도 > 증평군  22.548167       16090      안심지역
# 충청북도 > 진천군  22.780346       37427      안심지역
# 충청북도 > 청원구  26.843240       82572      안심지역
# 충청북도 > 충주시  19.566335       95281      안심지역
# 충청북도 > 흥덕구  24.783047      113965      안심지역
#
# [222 rows x 3 columns]

# %%
hwm_rate_g1 = pd.DataFrame(hwm_rate1['2020'])
hwm_rate_g1['total_2020']=total_hh['2020']
hwm_rate_g1['인구감소지수 분류']=hwm_rate1['인구감소지수 분류']
hwm_rate_g1
# Out:
#                  2020  total_2020 인구감소지수 분류
# sigungu
# 강원도 > 강릉시    7.976067       99109      관심지역
# 강원도 > 고성군    5.952381       12096    인구감소지역
# 강원도 > 동해시    9.315835       37871      관심지역
# 강원도 > 삼척시    6.644957       31016    인구감소지역
# 강원도 > 속초시    9.456600       35922      관심지역
# ...               ...         ...       ...
# 충청북도 > 증평군   8.638906       16090      안심지역
# 충청북도 > 진천군   8.945414       37427      안심지역
# 충청북도 > 청원구  10.145086       82572      안심지역
# 충청북도 > 충주시   7.968010       95281      안심지역
# 충청북도 > 흥덕구   9.531874      113965      안심지역
#
# [222 rows x 3 columns]

# %%
hwm_rate_g2 = pd.DataFrame(hwm_rate2['2020'])
hwm_rate_g2['total_2020']=total_hh['2020']
hwm_rate_g2['인구감소지수 분류']=hwm_rate2['인구감소지수 분류']
hwm_rate_g2
# Out:
#                  2020  total_2020 인구감소지수 분류
# sigungu
# 강원도 > 강릉시    8.787295       99109      관심지역
# 강원도 > 고성군    5.464616       12096    인구감소지역
# 강원도 > 동해시   10.849991       37871      관심지역
# 강원도 > 삼척시    7.180165       31016    인구감소지역
# 강원도 > 속초시    9.734981       35922      관심지역
# ...               ...         ...       ...
# 충청북도 > 증평군  10.540709       16090      안심지역
# 충청북도 > 진천군  10.890534       37427      안심지역
# 충청북도 > 청원구  13.545754       82572      안심지역
# 충청북도 > 충주시   9.393268       95281      안심지역
# 충청북도 > 흥덕구  12.299390      113965      안심지역
#
# [222 rows x 3 columns]

# %%
hwm_rate_g3 = pd.DataFrame(hwm_rate3['2020'])
hwm_rate_g3['total_2020']=total_hh['2020']
hwm_rate_g3['인구감소지수 분류']=hwm_rate3['인구감소지수 분류']
hwm_rate_g3
# Out:
#                 2020  total_2020 인구감소지수 분류
# sigungu
# 강원도 > 강릉시   1.807101       99109      관심지역
# 강원도 > 고성군   1.683821       12096    인구감소지역
# 강원도 > 동해시   2.643183       37871      관심지역
# 강원도 > 삼척시   1.763606       31016    인구감소지역
# 강원도 > 속초시   2.073938       35922      관심지역
# ...              ...         ...       ...
# 충청북도 > 증평군  3.368552       16090      안심지역
# 충청북도 > 진천군  2.944398       37427      안심지역
# 충청북도 > 청원구  3.152400       82572      안심지역
# 충청북도 > 충주시  2.205057       95281      안심지역
# 충청북도 > 흥덕구  2.951783      113965      안심지역
#
# [222 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rc

rc('font', family='AppleGothic')
sns.set(font='AppleGothic', rc={'axes.unicode_minus':False}, style='darkgrid')

sns.scatterplot(x='total_2020', 
                y='2020', 
                hue='인구감소지수 분류', # different colors by group
                style='인구감소지수 분류', # different shapes by group
                s=80, # marker size
                data=hwm_rate_g)

plt.title('2020년 미성년자녀 부양가구 비율')
plt.xlabel('가구수')
plt.ylabel('미성년자녀 부양가구 비율')

plt.savefig('output/household_w_minors_sum_rate_2020.png')
plt.show()

# %%
sns.scatterplot(x='total_2020', 
                y='2020', 
                hue='인구감소지수 분류', # different colors by group
                style='인구감소지수 분류', # different shapes by group
                s=80, # marker size
                data=hwm_rate_g1)

plt.title('2020년 미성년 1자녀 부양가구 비율')
plt.xlabel('가구수')
plt.ylabel('미성년 1자녀 부양가구 비율')

plt.savefig('output/household_w_minors_1_rate_2020.png')
plt.show()

# %%
sns.scatterplot(x='total_2020', 
                y='2020', 
                hue='인구감소지수 분류', # different colors by group
                style='인구감소지수 분류', # different shapes by group
                s=80, # marker size
                data=hwm_rate_g2)

plt.title('2020년 미성년 2자녀 부양가구 비율')
plt.xlabel('가구수')
plt.ylabel('미성년 2자녀 부양가구 비율')

plt.savefig('output/household_w_minors_2_rate_2020.png')
plt.show()

# %%
sns.scatterplot(x='total_2020', 
                y='2020', 
                hue='인구감소지수 분류', # different colors by group
                style='인구감소지수 분류', # different shapes by group
                s=80, # marker size
                data=hwm_rate_g3)

plt.title('2020년 미성년 3자녀이상 부양가구 비율')
plt.xlabel('가구수')
plt.ylabel('미성년 3자녀이상 부양가구 비율')

plt.savefig('output/household_w_minors_3_rate_2020.png')
plt.show()

# %%
hwm_89_sum = hwm_rate[hwm_rate['인구감소지수 분류'].isin(['인구감소지역'])]
hwm_89_sum
# Out:
#                  2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 > 고성군   14.583333  15.390220  14.424024  14.576691  12.946429    인구감소지역
# 강원도 > 삼척시   19.546396  18.753440  17.834545  17.031910  15.588728    인구감소지역
# 강원도 > 양구군   22.428420  22.986072  22.176143  23.339526  21.856844    인구감소지역
# 강원도 > 양양군   17.352967  16.527197  15.494411  14.482530  13.869024    인구감소지역
# 강원도 > 영월군   16.931022  15.857644  14.810172  13.915123  13.379913    인구감소지역
# ...               ...        ...        ...        ...        ...       ...
# 충청북도 > 단양군  16.323565  15.316760  14.206237  12.751153  12.222655    인구감소지역
# 충청북도 > 보은군  16.389208  15.829431  14.828337  13.536534  12.790376    인구감소지역
# 충청북도 > 영동군  16.651644  16.447617  15.687479  14.909696  13.918227    인구감소지역
# 충청북도 > 옥천군  20.232535  19.409324  18.296117  17.190765  16.076802    인구감소지역
# 충청북도 > 제천시  23.664040  22.545641  21.628222  20.206189  18.534891    인구감소지역
#
# [89 rows x 6 columns]

# %%
hwm_89_one = hwm_rate1[hwm_rate1['인구감소지수 분류'].isin(['인구감소지역'])]
hwm_89_one
# Out:
#                 2016      2017      2018       2019      2020 인구감소지수 분류
# sigungu
# 강원도 > 고성군   6.700244  7.019106  6.727929   6.783564  5.952381    인구감소지역
# 강원도 > 삼척시   8.243642  8.066181  7.778002   7.425291  6.644957    인구감소지역
# 강원도 > 양구군   9.247084  9.593315  9.854851  10.369252  8.982106    인구감소지역
# 강원도 > 양양군   7.821180  7.522664  7.067928   6.473566  5.986340    인구감소지역
# 강원도 > 영월군   7.291282  7.045152  6.721585   6.174537  5.804949    인구감소지역
# ...              ...       ...       ...        ...       ...       ...
# 충청북도 > 단양군  6.853960  6.704090  6.143238   5.660230  5.270533    인구감소지역
# 충청북도 > 보은군  6.687715  6.513410  6.529523   5.737013  5.199115    인구감소지역
# 충청북도 > 영동군  6.347550  6.377648  6.347781   6.126426  5.473408    인구감소지역
# 충청북도 > 옥천군  7.388453  7.126630  6.990291   6.731470  6.094474    인구감소지역
# 충청북도 > 제천시  9.314112  8.947917  8.668154   8.280376  7.486747    인구감소지역
#
# [89 rows x 6 columns]

# %%
hwm_89_two = hwm_rate2[hwm_rate2['인구감소지수 분류'].isin(['인구감소지역'])]
hwm_89_two
# Out:
#                  2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 > 고성군    6.196581   6.557642   6.079751   6.243358   5.464616    인구감소지역
# 강원도 > 삼척시    9.068686   8.626857   8.060716   7.702178   7.180165    인구감소지역
# 강원도 > 양구군   10.477200  10.562674   9.712976  10.044124  10.027888    인구감소지역
# 강원도 > 양양군    7.812362   7.252441   6.680997   6.440368   6.203294    인구감소지역
# 강원도 > 영월군    7.598672   6.996732   6.500716   6.222355   6.125182    인구감소지역
# ...               ...        ...        ...        ...        ...       ...
# 충청북도 > 단양군   7.160733   6.238974   5.994358   5.222422   5.114831    인구감소지역
# 충청북도 > 보은군   6.902985   6.726266   5.918697   5.659580   5.530973    인구감소지역
# 충청북도 > 영동군   7.671142   7.465015   6.815711   6.492395   6.271417    인구감소지역
# 충청북도 > 옥천군   9.544867   9.112011   8.344660   7.800729   7.431819    인구감소지역
# 충청북도 > 제천시  11.481017  10.808900  10.282672   9.471921   8.744786    인구감소지역
#
# [89 rows x 6 columns]

# %%
hwm_89_three = hwm_rate3[hwm_rate3['인구감소지수 분류'].isin(['인구감소지역'])]
hwm_89_three
# Out:
#                 2016      2017      2018      2019      2020 인구감소지수 분류
# sigungu
# 강원도 > 고성군   1.686508  1.813472  1.791221  1.725558  1.683821    인구감소지역
# 강원도 > 삼척시   2.234068  2.060402  1.995827  1.904440  1.763606    인구감소지역
# 강원도 > 양구군   2.704136  2.830084  2.608316  2.926150  2.846851    인구감소지역
# 강원도 > 양양군   1.905902  1.925629  1.928753  1.741638  1.845520    인구감소지역
# 강원도 > 영월군   2.041067  1.815761  1.587870  1.518231  1.449782    인구감소지역
# ...              ...       ...       ...       ...       ...       ...
# 충청북도 > 단양군  2.308872  2.373697  2.068641  1.868501  1.982678    인구감소지역
# 충청북도 > 보은군  2.798507  2.589755  2.380117  2.279671  2.060288    인구감소지역
# 충청북도 > 영동군  2.632952  2.604955  2.523987  2.290875  2.173403    인구감소지역
# 충청북도 > 옥천군  3.299215  3.170684  2.961165  2.658566  2.550509    인구감소지역
# 충청북도 > 제천시  2.868911  2.788823  2.677395  2.453892  2.303359    인구감소지역
#
# [89 rows x 6 columns]

# %%
hwm_18_sum = hwm_rate[hwm_rate['인구감소지수 분류'].isin(['관심지역'])]
hwm_18_sum
# Out:
#                   2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 > 강릉시    24.150635  22.786807  21.761255  20.425879  18.570463      관심지역
# 강원도 > 동해시    27.949334  26.856812  25.578965  24.073417  22.809010      관심지역
# 강원도 > 속초시    26.806147  25.301277  23.909779  22.590449  21.265520      관심지역
# 강원도 > 인제군    23.500499  23.204420  22.080943  21.799502  20.948181      관심지역
# 경기도 > 동두천시   27.675910  26.233951  24.539861  22.768950  21.218794      관심지역
# 경기도 > 포천시    24.599001  23.109216  21.365946  19.646728  18.012276      관심지역
# 경상남도 > 사천시   26.059620  25.180282  24.061124  22.425546  21.332798      관심지역
# 경상남도 > 통영시   27.704265  26.656649  25.447159  23.954100  22.593860      관심지역
# 경상북도 > 경주시   22.205853  21.176598  19.971491  18.735289  17.613266      관심지역
# 경상북도 > 김천시   23.381836  22.848950  21.837255  20.734520  19.617416      관심지역
# 광주광역시 > 동구   17.750668  17.070017  16.500034  16.537982  16.585396      관심지역
# ...

# %%
hwm_18_one = hwm_rate1[hwm_rate1['인구감소지수 분류'].isin(['관심지역'])]
hwm_18_one
# Out:
#                   2016       2017       2018       2019      2020 인구감소지수 분류
# sigungu
# 강원도 > 강릉시     9.943786   9.619650   9.375342   8.796923  7.976067      관심지역
# 강원도 > 동해시    11.162624  10.897896  10.501128   9.832573  9.315835      관심지역
# 강원도 > 속초시    11.735048  11.342364  10.927240  10.136035  9.456600      관심지역
# 강원도 > 인제군     9.676676   9.828029   9.435571   9.414881  9.119546      관심지역
# 경기도 > 동두천시   10.840831  10.287308   9.703321   9.083095  8.426578      관심지역
# 경기도 > 포천시     9.196687   8.783364   8.321980   7.789643  6.998320      관심지역
# 경상남도 > 사천시   10.191699   9.843719   9.686610   9.072143  8.659389      관심지역
# 경상남도 > 통영시   10.858921  10.546474  10.040626   9.564354  8.858017      관심지역
# 경상북도 > 경주시    9.051811   8.648961   8.284556   7.846041  7.303438      관심지역
# 경상북도 > 김천시    9.201849   9.125243   8.877330   8.575706  7.988269      관심지역
# 광주광역시 > 동구    6.780435   6.675134   6.573017   6.896476  6.882742      관심지역
# ...

# %%
hwm_18_two = hwm_rate2[hwm_rate2['인구감소지수 분류'].isin(['관심지역'])]
hwm_18_two
# Out:
#                   2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 > 강릉시    11.902309  10.991206  10.348224   9.687574   8.787295      관심지역
# 강원도 > 동해시    13.618677  12.874814  12.107377  11.542348  10.849991      관심지역
# 강원도 > 속초시    12.737373  11.677282  10.874238  10.341534   9.734981      관심지역
# 강원도 > 인제군    11.028339  10.855186  10.133354   9.864355   9.505434      관심지역
# 경기도 > 동두천시   13.600507  12.807830  11.872360  10.877833  10.078095      관심지역
# 경기도 > 포천시    11.947804  11.150315  10.179679   9.191489   8.433149      관심지역
# 경상남도 > 사천시   12.897907  12.513425  11.672278  10.792388  10.219810      관심지역
# 경상남도 > 통영시   13.536339  12.948981  12.331109  11.504441  11.059320      관심지역
# 경상북도 > 경주시   10.947823  10.430372   9.722482   9.053803   8.583794      관심지역
# 경상북도 > 김천시   11.569063  11.219905  10.617538  10.007572   9.514605      관심지역
# 광주광역시 > 동구    8.354465   8.038286   7.726098   7.587655   7.725188      관심지역
# ...

# %%
hwm_18_three = hwm_rate3[hwm_rate3['인구감소지수 분류'].isin(['관심지역'])]
hwm_18_three
# Out:
#                  2016      2017      2018      2019      2020 인구감소지수 분류
# sigungu
# 강원도 > 강릉시    2.304540  2.175952  2.037690  1.941382  1.807101      관심지역
# 강원도 > 동해시    3.168033  3.084102  2.970460  2.698495  2.643183      관심지역
# 강원도 > 속초시    2.394555  2.281630  2.108301  2.167438  2.073938      관심지역
# 강원도 > 인제군    2.965581  2.683902  2.512017  2.520266  2.478146      관심지역
# 경기도 > 동두천시   3.234572  3.138813  2.964180  2.808023  2.714121      관심지역
# 경기도 > 포천시    3.454510  3.175537  2.864287  2.665596  2.580807      관심지역
# 경상남도 > 사천시   2.970014  2.823137  2.702236  2.561015  2.453599      관심지역
# 경상남도 > 통영시   3.309004  3.161193  3.075424  2.885305  2.676523      관심지역
# 경상북도 > 경주시   2.206219  2.097265  1.964453  1.835445  1.726033      관심지역
# 경상북도 > 김천시   2.610924  2.503803  2.342386  2.151241  2.114542      관심지역
# 광주광역시 > 동구   2.615768  2.356597  2.200920  2.053851  1.977466      관심지역
# 대전광역시 > 대덕구  3.666129  3.456106  3.181381  2.942184  2.688881      관심지역
# ...

# %%
hwm_non_sum = hwm_rate[hwm_rate['인구감소지수 분류'].isin(['안심지역'])]
hwm_non_sum
# Out:
#                  2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 > 원주시   29.465987  28.146724  26.728827  25.354161  23.919493      안심지역
# 강원도 > 춘천시   27.743916  26.428724  25.383405  24.278781  22.986586      안심지역
# 경기도 > 과천시   34.116436  33.535440  32.408441  31.383063  30.612245      안심지역
# 경기도 > 광명시   33.514518  31.807205  29.896079  28.311723  27.575117      안심지역
# 경기도 > 광주시   31.906808  30.744264  29.534509  28.073528  26.727009      안심지역
# ...               ...        ...        ...        ...        ...       ...
# 충청북도 > 증평군  28.572391  27.592556  25.903146  24.157446  22.548167      안심지역
# 충청북도 > 진천군  25.283585  24.680483  24.355860  23.765624  22.780346      안심지역
# 충청북도 > 청원구  32.711077  31.843208  30.367966  28.484378  26.843240      안심지역
# 충청북도 > 충주시  24.119160  22.982777  21.908369  20.618087  19.566335      안심지역
# 충청북도 > 흥덕구  30.736655  28.915686  27.489372  26.202511  24.783047      안심지역
#
# [115 rows x 6 columns]

# %%
hwm_non_one = hwm_rate1[hwm_rate1['인구감소지수 분류'].isin(['안심지역'])]
hwm_non_one
# Out:
#                  2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 > 원주시   11.313935  11.081654  10.647069  10.283190   9.702811      안심지역
# 강원도 > 춘천시   10.565714  10.346266  10.127656   9.778881   9.215516      안심지역
# 경기도 > 과천시   12.532759  12.341042  12.241535  12.311413  11.949198      안심지역
# 경기도 > 광명시   12.923610  12.405276  11.950482  11.396162  10.859800      안심지역
# 경기도 > 광주시   12.860982  12.598929  12.378863  11.901981  11.269227      안심지역
# ...               ...        ...        ...        ...        ...       ...
# 충청북도 > 증평군  10.685171  10.475439   9.737149   9.283988   8.638906      안심지역
# 충청북도 > 진천군   9.214338   9.327653   9.427397   9.442339   8.945414      안심지역
# 충청북도 > 청원구  12.130606  12.018239  11.566825  11.084029  10.145086      안심지역
# 충청북도 > 충주시   9.596688   9.291659   9.133272   8.616352   7.968010      안심지역
# 충청북도 > 흥덕구  11.074029  10.495381  10.169557  10.065356   9.531874      안심지역
#
# [115 rows x 6 columns]

# %%
hwm_non_two = hwm_rate2[hwm_rate2['인구감소지수 분류'].isin(['안심지역'])]
hwm_non_two
# Out:
#                  2016       2017       2018       2019       2020 인구감소지수 분류
# sigungu
# 강원도 > 원주시   14.930734  14.030282  13.189588  12.362928  11.620563      안심지역
# 강원도 > 춘천시   13.995214  13.086575  12.414095  11.834669  11.267770      안심지역
# 경기도 > 과천시   18.443467  18.130600  17.200872  16.301319  16.035678      안심지역
# 경기도 > 광명시   17.590516  16.573123  15.328945  14.461093  14.255126      안심지역
# 경기도 > 광주시   15.514319  14.822927  14.036371  13.205076  12.551451      안심지역
# ...               ...        ...        ...        ...        ...       ...
# 충청북도 > 증평군  13.541737  12.954560  12.229703  11.261605  10.540709      안심지역
# 충청북도 > 진천군  12.362570  11.832538  11.542038  11.252192  10.890534      안심지역
# 충청북도 > 청원구  16.716980  16.121996  15.275533  14.186178  13.545754      안심지역
# 충청북도 > 충주시  11.756836  11.111616  10.367826   9.716981   9.393268      안심지역
# 충청북도 > 흥덕구  15.790800  14.783069  13.869603  13.009146  12.299390      안심지역
#
# [115 rows x 6 columns]

# %%
hwm_non_three = hwm_rate3[hwm_rate3['인구감소지수 분류'].isin(['안심지역'])]
hwm_non_three
# Out:
#                 2016      2017      2018      2019      2020 인구감소지수 분류
# sigungu
# 강원도 > 원주시   3.221318  3.034789  2.892170  2.708043  2.596118      안심지역
# 강원도 > 춘천시   3.182988  2.995882  2.841654  2.665231  2.503299      안심지역
# 경기도 > 과천시   3.234502  3.170619  2.966034  2.869421  2.627369      안심지역
# 경기도 > 광명시   3.000392  2.828806  2.616652  2.454467  2.460191      안심지역
# 경기도 > 광주시   3.531506  3.322408  3.119276  2.966471  2.906331      안심지역
# ...              ...       ...       ...       ...       ...       ...
# 충청북도 > 증평군  4.345483  4.162557  3.936294  3.611853  3.368552      안심지역
# 충청북도 > 진천군  3.706677  3.520292  3.386424  3.071093  2.944398      안심지역
# 충청북도 > 청원구  3.863492  3.702974  3.525609  3.214171  3.152400      안심지역
# 충청북도 > 충주시  2.765636  2.579502  2.407270  2.284754  2.205057      안심지역
# 충청북도 > 흥덕구  3.871826  3.637236  3.450213  3.128009  2.951783      안심지역
#
# [115 rows x 6 columns]

# %%
hwm_mean = pd.DataFrame({'인구감소지역':hwm_89_sum.mean()})
hwm_mean['관심지역']=hwm_18_sum.mean()
hwm_mean['안심지역']=hwm_non_sum.mean()
hwm_mean['전국']=hwm_rate.mean()

hwm_mean
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_5922/1760334950.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   hwm_mean = pd.DataFrame({'인구감소지역':hwm_89_sum.mean()})
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_5922/1760334950.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   hwm_mean['관심지역']=hwm_18_sum.mean()
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_5922/1760334950.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# ...

# %%
hwm_mean1 = pd.DataFrame({'인구감소지역':hwm_89_one.mean()})
hwm_mean1['관심지역']=hwm_18_one.mean()
hwm_mean1['안심지역']=hwm_non_one.mean()
hwm_mean1['전국']=hwm_rate1.mean()

hwm_mean1
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_5922/3701828866.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   hwm_mean1 = pd.DataFrame({'인구감소지역':hwm_89_one.mean()})
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_5922/3701828866.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   hwm_mean1['관심지역']=hwm_18_one.mean()
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_5922/3701828866.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# ...

# %%
hwm_mean2 = pd.DataFrame({'인구감소지역':hwm_89_two.mean()})
hwm_mean2['관심지역']=hwm_18_two.mean()
hwm_mean2['안심지역']=hwm_non_two.mean()
hwm_mean2['전국']=hwm_rate2.mean()

hwm_mean2
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_5922/3018119100.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   hwm_mean2 = pd.DataFrame({'인구감소지역':hwm_89_two.mean()})
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_5922/3018119100.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   hwm_mean2['관심지역']=hwm_18_two.mean()
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_5922/3018119100.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# ...

# %%
hwm_mean3 = pd.DataFrame({'인구감소지역':hwm_89_three.mean()})
hwm_mean3['관심지역']=hwm_18_three.mean()
hwm_mean3['안심지역']=hwm_non_three.mean()
hwm_mean3['전국']=hwm_rate3.mean()

hwm_mean3
# Out:
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_5922/3675957615.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   hwm_mean3 = pd.DataFrame({'인구감소지역':hwm_89_three.mean()})
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_5922/3675957615.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   hwm_mean3['관심지역']=hwm_18_three.mean()
# /var/folders/n2/4d2sw9gd3z9c6ld6fljb35440000gn/T/ipykernel_5922/3675957615.py:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# ...

# %%
df1=hwm_mean.plot(kind='bar')

plt.title('5년간 미성년자녀 부양가구 변화')

plt.xticks(rotation=0)
plt.xlabel('연도')
plt.ylabel('미성년자녀 부양가구 평균')
lgd=df1.legend(bbox_to_anchor=(1,1))

plt.savefig('output/hwm_sum_5years_mean_bar.png',bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()

# %%
df2=hwm_mean1.plot(kind='bar')

plt.title('5년간 미성년 1자녀 부양가구 변화')

plt.xticks(rotation=0)
plt.xlabel('연도')
plt.ylabel('미성년 1자녀 부양가구 평균')
lgd=df2.legend(bbox_to_anchor=(1,1))

plt.savefig('output/hwm_one_5years_mean_bar.png',bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()

# %%
df3=hwm_mean2.plot(kind='bar')

plt.title('5년간 미성년 2자녀 부양가구 변화')

plt.xticks(rotation=0)
plt.xlabel('연도')
plt.ylabel('미성년 2자녀 부양가구 평균')
lgd=df3.legend(bbox_to_anchor=(1,1))

plt.savefig('output/hwm_two_5years_mean_bar.png',bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()

# %%
df4=hwm_mean3.plot(kind='bar')

plt.title('5년간 미성년 3자녀 부양가구 변화')

plt.xticks(rotation=0)
plt.xlabel('연도')
plt.ylabel('미성년 3자녀 부양가구 평균')
lgd=df4.legend(bbox_to_anchor=(1,1))

plt.savefig('output/hwm_three_5years_mean_bar.png',bbox_extra_artists=(lgd,), bbox_inches='tight')
plt.show()

# %%
plt.style.use('ggplot')
fig=plt.figure(figsize=(8,5))
ax=fig.add_subplot(1,1,1)

ax.plot(hwm_mean['인구감소지역'],marker='o',markerfacecolor='olive',markersize=8,color='green',label='인구감소지역')
ax.plot(hwm_mean['관심지역'],marker='o',markerfacecolor='orange',markersize=8,color='yellow',label='관심지역')
ax.plot(hwm_mean['안심지역'],marker='o',markerfacecolor='red',markersize=8,color='magenta',label='안심지역')
ax.plot(hwm_mean['전국'],marker='o',markerfacecolor='indigo',markersize=8,color='skyblue',label='전국')

ax.legend(loc='best')
ax.set_title('5년간 미성년자녀 부양가구의 변화')
ax.set_ylabel('미성년자녀 부양가구의 평균')
ax.set_xlabel('연도')

plt.savefig('output/hwm_sum_5years_mean_line.png')
plt.show()

# %%
plt.style.use('ggplot')
fig=plt.figure(figsize=(8,5))
ax=fig.add_subplot(1,1,1)

ax.plot(hwm_mean1['인구감소지역'],marker='o',markerfacecolor='olive',markersize=8,color='green',label='인구감소지역')
ax.plot(hwm_mean1['관심지역'],marker='o',markerfacecolor='orange',markersize=8,color='yellow',label='관심지역')
ax.plot(hwm_mean1['안심지역'],marker='o',markerfacecolor='red',markersize=8,color='magenta',label='안심지역')
ax.plot(hwm_mean1['전국'],marker='o',markerfacecolor='indigo',markersize=8,color='skyblue',label='전국')

ax.legend(loc='best')
ax.set_title('5년간 미성년 1자녀 부양가구의 변화')
ax.set_ylabel('미성년 1자녀 부양가구의 평균')
ax.set_xlabel('연도')

plt.savefig('output/hwm_one_5years_mean_line.png')
plt.show()

# %%
plt.style.use('ggplot')
fig=plt.figure(figsize=(8,5))
ax=fig.add_subplot(1,1,1)

ax.plot(hwm_mean2['인구감소지역'],marker='o',markerfacecolor='olive',markersize=8,color='green',label='인구감소지역')
ax.plot(hwm_mean2['관심지역'],marker='o',markerfacecolor='orange',markersize=8,color='yellow',label='관심지역')
ax.plot(hwm_mean2['안심지역'],marker='o',markerfacecolor='red',markersize=8,color='magenta',label='안심지역')
ax.plot(hwm_mean2['전국'],marker='o',markerfacecolor='indigo',markersize=8,color='skyblue',label='전국')

ax.legend(loc='best')
ax.set_title('5년간 미성년 2자녀 부양가구의 변화')
ax.set_ylabel('미성년 2자녀 부양가구의 평균')
ax.set_xlabel('연도')

plt.savefig('output/hwm_two_5years_mean_line.png')
plt.show()

# %%
plt.style.use('ggplot')
fig=plt.figure(figsize=(8,5))
ax=fig.add_subplot(1,1,1)

ax.plot(hwm_mean3['인구감소지역'],marker='o',markerfacecolor='olive',markersize=8,color='green',label='인구감소지역')
ax.plot(hwm_mean3['관심지역'],marker='o',markerfacecolor='orange',markersize=8,color='yellow',label='관심지역')
ax.plot(hwm_mean3['안심지역'],marker='o',markerfacecolor='red',markersize=8,color='magenta',label='안심지역')
ax.plot(hwm_mean3['전국'],marker='o',markerfacecolor='indigo',markersize=8,color='skyblue',label='전국')

ax.legend(loc='best')
ax.set_title('5년간 미성년 3자녀 부양가구의 변화')
ax.set_ylabel('미성년 3자녀 부양가구의 평균')
ax.set_xlabel('연도')

plt.savefig('output/hwm_three_5years_mean_line.png')
plt.show()
